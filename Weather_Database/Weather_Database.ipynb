# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library  
import time

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | tezu
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | ancud
# Processing Record 6 of Set 1 | kupang
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | ugoofaaru
# Processing Record 9 of Set 1 | sao joao da barra
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | northam
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | pisco
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 1 | clyde river
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | praia
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | gigmoto
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | luderitz
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | oistins
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | otterup
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | catuday
# Processing Record 39 of Set 1 | guapi
# Processing Record 40 of Set 1 | tignere
# Processing Record 41 of Set 1 | myskhako
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | alofi
# Processing Record 45 of Set 1 | grindavik
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | vitim
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | los llanos de aridane
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | san carlos de bariloche
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | cayenne
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | haimen
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | bafoulabe
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | zheshart
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | college
# Processing Record 16 of Set 2 | rikitea
# Processing Record 17 of Set 2 | mehamn
# Processing Record 18 of Set 2 | richards bay
# Processing Record 19 of Set 2 | alta gracia
# Processing Record 20 of Set 2 | oussouye
# Processing Record 21 of Set 2 | strezhevoy
# Processing Record 22 of Set 2 | auki
# Processing Record 23 of Set 2 | lusambo
# Processing Record 24 of Set 2 | pacific grove
# Processing Record 25 of Set 2 | nome
# Processing Record 26 of Set 2 | hendek
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | nalut
# Processing Record 30 of Set 2 | cap malheureux
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | fukue
# Processing Record 33 of Set 2 | acarau
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | bandar-e anzali
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | xiongshi
# City not found. Skipping...
# Processing Record 41 of Set 2 | imeni poliny osipenko
# Processing Record 42 of Set 2 | narsaq
# Processing Record 43 of Set 2 | niltepec
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | arona
# Processing Record 49 of Set 2 | betioky
# Processing Record 50 of Set 2 | margate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 12>()
#      16     set_count += 1
#      17     record_count = 1
# ---> 18     time.sleep(60)
#      20 # Create endpoint URL with each city.
#      21 city_url = url + "&q=" + city.replace(" ","+")
#
# KeyboardInterrupt:

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Punta Arenas      CL -53.1500  -70.9167     32.11        86
# 1       Puerto Ayora      EC  -0.7393  -90.3518     67.55        98
# 2               Tezu      IN  27.9167   96.1667     76.84        98
# 3             Torbay      CA  47.6666  -52.7314     61.57        88
# 4              Ancud      CL -41.8697  -73.8203     39.22        91
# 5             Kupang      ID -10.1667  123.5833     86.07        40
# 6          Jamestown      US  42.0970  -79.2353     72.72        79
# 7          Ugoofaaru      MV   5.6667   73.0000     82.22        77
# 8  Sao Joao Da Barra      BR -21.6403  -41.0511     68.81        88
# 9             Albany      US  42.6001  -73.9662     73.81        81
#
#    Cloudiness  Wind Speed Current Description
# 0          20       18.41          few clouds
# 1          39        3.00    scattered clouds
# 2         100        0.81       moderate rain
# 3         100        5.75     overcast clouds
# 4         100        5.41     overcast clouds
# 5          76       12.46       broken clouds
# 6           0        5.75           clear sky
# 7         100       16.67     overcast clouds
# 8           6        6.33           clear sky
# 9           0        4.76           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
